# %%
from elasticsearch import Elasticsearch

es = Elasticsearch("http://localhost:9200")

print(es.info())
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/anaconda3/envs/test/lib/python3.10/site-packages/urllib3/connection.py:204, in HTTPConnection._new_conn(self)
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#
# File ~/anaconda3/envs/test/lib/python3.10/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...

# %%
doc = {
    "name": "Ali",
    "age": 22,
    "city": "Casablanca"
}

es.index(index="students_3", document=doc)
# Out:
# ObjectApiResponse({'_index': 'students_3', '_id': 'a8u8SJ0B8T-yX4PrgRpY', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 0, '_primary_term': 1})

# %%
res = es.search(
    index = "students_2",
    query = {
        "match_all": {}
    }
)

print(res)
# Out:
# {'took': 5, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 4, 'relation': 'eq'}, 'max_score': 1.0, 'hits': [{'_index': 'students_2', '_id': 'Z8vNR50B8T-yX4PrORpR', '_score': 1.0, '_source': {'name': 'Ali', 'age': 22, 'city': 'Casablanca', 'skills': 'java spring'}}, {'_index': 'students_2', '_id': 'aMvNR50B8T-yX4PrORpR', '_score': 1.0, '_source': {'name': 'sara', 'age': '24', 'city': 'Rabat', 'skills': 'python django'}}, {'_index': 'students_2', '_id': 'acvNR50B8T-yX4PrORpR', '_score': 1.0, '_source': {'name': 'Youssef', 'age': 21, 'city': 'Casablanca', 'skills': 'javascript react'}}, {'_index': 'students_2', '_id': 'asvNR50B8T-yX4PrORpR', '_score': 1.0, '_source': {'name': 'Nadia', 'age': 25, 'city': 'Marrakech', 'skills': 'java angular'}}]}}

# %%
import pandas as pd

data = [hit["_source"] for hit in res["hits"]["hits"]]
df = pd.DataFrame(data)

df
# Out:
#       name age        city            skills
# 0      Ali  22  Casablanca       java spring
# 1     sara  24       Rabat     python django
# 2  Youssef  21  Casablanca  javascript react
# 3    Nadia  25   Marrakech      java angular
